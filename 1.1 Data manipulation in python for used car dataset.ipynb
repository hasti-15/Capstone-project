# %%
path=r"C:\Users\hasshah\Documents\Capstone3_UsedCarsData (1)\Capstone3_UsedCarsData\Car_sales_transactions.csv"

# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv(path)
car
# Out:
#       Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0            1        Maruti Swift Dzire VDI  2014         450000     145500
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2            3      Honda City 2017-2020 EXi  2006         158000     140000
# 3            4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4            5        Maruti Swift VXI BSIII  2007         130000     120000
# ...        ...                           ...   ...            ...        ...
# 7901      8124             Hyundai i20 Magna  2013         320000     110000
# 7902      8125         Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126        Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127               Tata Indigo CR4  2013         290000      25000
# 7905      8128               Tata Indigo CR4  2013         290000      25000
#
# ...

# %%
car.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats'],
#       dtype='object')

# %%
car.shape
# Out:
# (7906, 16)

# %%
car.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 0      CT01       ST15       400001  Diesel  Individual       Manual
# 1      CT28       ST11       834001  Diesel  Individual       Manual
# 2      CT12       ST28       201301  Petrol  Individual       Manual
# 3      CT21       ST27       248001  Diesel  Individual       Manual
# 4      CT03       ST24       600020  Petrol  Individual       Manual
#
#           Owner     Mileage   Engine   Max_Power  Seats
# ...

# %%
car.tail()
# Out:
#       Sales_ID                    Name  Year  Selling_Price  km_Driven  \
# 7901      8124       Hyundai i20 Magna  2013         320000     110000
# 7902      8125   Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126  Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127         Tata Indigo CR4  2013         290000      25000
# 7905      8128         Tata Indigo CR4  2013         290000      25000
#
#      City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 7901      CT22       ST14       452010  Petrol  Individual       Manual
# 7902      CT21       ST27       248001  Diesel  Individual       Manual
# 7903      CT08       ST29       700005  Diesel  Individual       Manual
# 7904      CT29       ST24       632001  Diesel  Individual       Manual
# 7905      CT21       ST27       248001  Diesel  Individual       Manual
#
#                      Owner     Mileage   Engine  Max_Power  Seats
# ...

# %%
car.describe()
# Out:
#           Sales_ID         Year  Selling_Price     km_Driven    Postal_Code  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03    7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04  503562.180116
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04  204939.677172
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00  110001.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04  391510.000000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04  524225.000000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04  680001.000000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06  834001.000000
#
#              Seats
# count  7906.000000
# mean      5.416393
# std       0.959208
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%       5.000000
# max      14.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   Name           7906 non-null   object
#  2   Year           7906 non-null   int64
#  3   Selling_Price  7906 non-null   int64
#  4   km_Driven      7906 non-null   int64
#  5   City_Code      7906 non-null   object
#  6   State_Code     7906 non-null   object
#  7   Postal_Code    7906 non-null   int64
#  8   Fuel           7906 non-null   object
#  9   Seller_Type    7906 non-null   object
#  10  Transmission   7906 non-null   object
#  11  Owner          7906 non-null   object
#  12  Mileage        7906 non-null   object
#  13  Engine         7906 non-null   object
#  14  Max_Power      7906 non-null   object
#  15  Seats          7906 non-null   int64
# dtypes: int64(6), object(10)
# memory usage: 988.4+ KB

# %%
car['Brand']=car['Name'].apply(lambda x:' '.join(x.split()[:1]))
car['Model']=car['Name'].apply(lambda x:' '.join(x.split()[1:2]))
car['Variant']=car['Name'].apply(lambda x:' '.join(x.split()[2:]))

# %%
car.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 0      CT01       ST15       400001  Diesel  Individual       Manual
# 1      CT28       ST11       834001  Diesel  Individual       Manual
# 2      CT12       ST28       201301  Petrol  Individual       Manual
# 3      CT21       ST27       248001  Diesel  Individual       Manual
# 4      CT03       ST24       600020  Petrol  Individual       Manual
#
#           Owner     Mileage   Engine   Max_Power  Seats    Brand  Model  \
# ...

# %% [raw]
# # Which brands of car selling most

# %%
car['Brand'].value_counts()
# Out:
# Maruti           2367
# Hyundai          1360
# Mahindra          758
# Tata              719
# Honda             466
# Toyota            452
# Ford              388
# Chevrolet         230
# Renault           228
# Volkswagen        185
# BMW               118
# Skoda             104
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               41
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Name: Brand, dtype: int64

# %%
car['Brand'].value_counts().head(5)
# Out:
# Maruti      2367
# Hyundai     1360
# Mahindra     758
# Tata         719
# Honda        466
# Name: Brand, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sns.boxplot(car["Selling_Price"])
# Out:
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>

# %%
sns.histplot(car['Selling_Price'])
# Out:
# <AxesSubplot:xlabel='Selling_Price', ylabel='Count'>

# %%
corr_matrix=car.corr()
corr_matrix
# Out:
#                Sales_ID      Year  Selling_Price  km_Driven  Postal_Code  \
# Sales_ID       1.000000 -0.001304      -0.012125   0.009556    -0.010688
# Year          -0.001304  1.000000       0.412302  -0.428548     0.004898
# Selling_Price -0.012125  0.412302       1.000000  -0.222158     0.008682
# km_Driven      0.009556 -0.428548      -0.222158   1.000000    -0.005680
# Postal_Code   -0.010688  0.004898       0.008682  -0.005680     1.000000
# Seats         -0.014154 -0.007923       0.041617   0.227259    -0.004804
#
#                   Seats
# Sales_ID      -0.014154
# Year          -0.007923
# Selling_Price  0.041617
# km_Driven      0.227259
# Postal_Code   -0.004804
# Seats          1.000000

# %%
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %%
plt.scatter(car['km_Driven'],car['Selling_Price'])
plt.xlabel('Kilometers Driven')
plt.ylabel('Price')
plt.title('Price Vs Kilometers Driven')
# Out:
# Text(0.5, 1.0, 'Price Vs Kilometers Driven')

# %%
mx = sns.factorplot(y="Selling_Price", x="Seats", data=car,kind="box",size=12 ,aspect=1)
mx.set(ylabel='Selling_Price')
mx.set(xlabel= 'Seats')
plt.title('Price Vs Seats');
# Out:
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
mx = sns.factorplot(x="Selling_Price", y="Brand", data=car,kind="box",size=12 ,aspect=1)
mx.set(xlabel='Old Price/New Price')
mx.set(ylabel= 'Brand')
plt.title('Brand Vs  Price');
# Out:
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
mx1 = sns.factorplot(x="Selling_Price", y="Year", data=car,kind="box",size=12 ,aspect=1)
mx1.set(xlabel='Selling Price')
mx1.set(ylabel= 'Year')
plt.title('Year Vs Price');
# Out:
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\hasshah\Anaconda3\lib\site-packages\seaborn\categorical.py:3723: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import pandas as pd
path2=r"C:\Users\hasshah\Documents\Capstone3_UsedCarsData (1)\Capstone3_UsedCarsData\City_Master.xlsx"

# %%
car2=pd.read_excel(path2)
car2
# Out:
#    City_Code     City_Name State_Code
# 0       CT01        Mumbai       ST15
# 1       CT02          Pune       ST15
# 2       CT03       Chennai       ST24
# 3       CT04    Coimbatore       ST24
# 4       CT05     Hyderabad       ST25
# 5       CT06        Jaipur       ST22
# 6       CT07         Kochi       ST13
# 7       CT08       Kolkata       ST29
# 8       CT09         Delhi       ST34
# 9       CT10     Bangalore       ST12
# 10      CT11     Ahmedabad       ST07
# 11      CT12         Noida       ST28
# 12      CT13         Patna       ST04
# 13      CT14         Surat       ST07
# 14      CT15  Bhubaneshwar       ST20
# 15      CT16       Gangtok       ST23
# 16      CT17      Vadodara       ST07
# 17      CT18      Ludhiana       ST21
# 18      CT19        Mysore       ST12
# 19      CT20        kanpur       ST28
# 20      CT21      Dehradun       ST27
# 21      CT22        Indore       ST14
# 22      CT23     Mangalore       ST12
# 23      CT24      Thrissur       ST13
# ...

# %%
merged_data = car.merge(car2,on=["City_Code"])
merged_data.head()
# Out:
#    Sales_ID                                 Name  Year  Selling_Price  \
# 0         1               Maruti Swift Dzire VDI  2014         450000
# 1        18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2        48               Toyota Fortuner 4x4 MT  2014        1500000
# 3        71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4       121              Nissan Terrano XL 85 PS  2014         400000
#
#    km_Driven City_Code State_Code_x  Postal_Code    Fuel Seller_Type  \
# 0     145500      CT01         ST15       400001  Diesel  Individual
# 1      53000      CT01         ST15       400001  Diesel  Individual
# 2      77000      CT01         ST15       400001  Diesel      Dealer
# 3      80000      CT01         ST15       400001  Diesel  Individual
# 4      70000      CT01         ST15       400001  Diesel  Individual
#
#   Transmission         Owner     Mileage   Engine   Max_Power  Seats  \
# ...
