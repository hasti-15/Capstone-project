# %% [markdown]
# # Used Car Dataset:

# %% [markdown]
# Problem Statement : An automobile company wants to enter the business of selling used cars. We have to analyze the data and understand the factors affecting the price of used cars.

# %% [markdown]
# Importing inbuilt libraries like numpy,pandas and csv file(dataset)

# %%
path=r"C:\Users\hasshah\Documents\Capstone3_UsedCarsData (1)\Capstone3_UsedCarsData\Car_sales_transactions.csv"

# %%
import pandas as pd
import numpy as np

# %%
car=pd.read_csv(path)
car
# Out:
#       Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0            1        Maruti Swift Dzire VDI  2014         450000     145500
# 1            2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2            3      Honda City 2017-2020 EXi  2006         158000     140000
# 3            4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4            5        Maruti Swift VXI BSIII  2007         130000     120000
# ...        ...                           ...   ...            ...        ...
# 7901      8124             Hyundai i20 Magna  2013         320000     110000
# 7902      8125         Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126        Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127               Tata Indigo CR4  2013         290000      25000
# 7905      8128               Tata Indigo CR4  2013         290000      25000
#
# ...

# %% [markdown]
# Understanding the dataset before pre-processing

# %%
car.columns
# Out:
# Index(['Sales_ID', 'Name', 'Year', 'Selling_Price', 'km_Driven', 'City_Code',
#        'State_Code', 'Postal_Code', 'Fuel', 'Seller_Type', 'Transmission',
#        'Owner', 'Mileage', 'Engine', 'Max_Power', 'Seats'],
#       dtype='object')

# %%
car.shape
# Out:
# (7906, 16)

# %%
car.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 0      CT01       ST15       400001  Diesel  Individual       Manual
# 1      CT28       ST11       834001  Diesel  Individual       Manual
# 2      CT12       ST28       201301  Petrol  Individual       Manual
# 3      CT21       ST27       248001  Diesel  Individual       Manual
# 4      CT03       ST24       600020  Petrol  Individual       Manual
#
#           Owner     Mileage   Engine   Max_Power  Seats
# ...

# %%
car.tail()
# Out:
#       Sales_ID                    Name  Year  Selling_Price  km_Driven  \
# 7901      8124       Hyundai i20 Magna  2013         320000     110000
# 7902      8125   Hyundai Verna CRDi SX  2007         135000     119000
# 7903      8126  Maruti Swift Dzire ZDi  2009         382000     120000
# 7904      8127         Tata Indigo CR4  2013         290000      25000
# 7905      8128         Tata Indigo CR4  2013         290000      25000
#
#      City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 7901      CT22       ST14       452010  Petrol  Individual       Manual
# 7902      CT21       ST27       248001  Diesel  Individual       Manual
# 7903      CT08       ST29       700005  Diesel  Individual       Manual
# 7904      CT29       ST24       632001  Diesel  Individual       Manual
# 7905      CT21       ST27       248001  Diesel  Individual       Manual
#
#                      Owner     Mileage   Engine  Max_Power  Seats
# ...

# %%
car.describe()
# Out:
#           Sales_ID         Year  Selling_Price     km_Driven    Postal_Code  \
# count  7906.000000  7906.000000   7.906000e+03  7.906000e+03    7906.000000
# mean   4070.106248  2013.983936   6.498137e+05  6.918866e+04  503562.180116
# std    2345.770159     3.863695   8.135827e+05  5.679230e+04  204939.677172
# min       1.000000  1994.000000   2.999900e+04  1.000000e+00  110001.000000
# 25%    2037.250000  2012.000000   2.700000e+05  3.500000e+04  391510.000000
# 50%    4076.500000  2015.000000   4.500000e+05  6.000000e+04  524225.000000
# 75%    6102.000000  2017.000000   6.900000e+05  9.542500e+04  680001.000000
# max    8128.000000  2020.000000   1.000000e+07  2.360457e+06  834001.000000
#
#              Seats
# count  7906.000000
# mean      5.416393
# std       0.959208
# min       2.000000
# 25%       5.000000
# 50%       5.000000
# 75%       5.000000
# max      14.000000

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7906 entries, 0 to 7905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   Name           7906 non-null   object
#  2   Year           7906 non-null   int64
#  3   Selling_Price  7906 non-null   int64
#  4   km_Driven      7906 non-null   int64
#  5   City_Code      7906 non-null   object
#  6   State_Code     7906 non-null   object
#  7   Postal_Code    7906 non-null   int64
#  8   Fuel           7906 non-null   object
#  9   Seller_Type    7906 non-null   object
#  10  Transmission   7906 non-null   object
#  11  Owner          7906 non-null   object
#  12  Mileage        7906 non-null   object
#  13  Engine         7906 non-null   object
#  14  Max_Power      7906 non-null   object
#  15  Seats          7906 non-null   int64
# dtypes: int64(6), object(10)
# memory usage: 988.4+ KB

# %% [markdown]
# Extracting Brand,Model and Variant from Name column for further processing

# %%
car['Brand']=car['Name'].apply(lambda x:' '.join(x.split()[:1]))
car['Model']=car['Name'].apply(lambda x:' '.join(x.split()[1:2]))
car['Variant']=car['Name'].apply(lambda x:' '.join(x.split()[2:]))

# %%
car.head()
# Out:
#    Sales_ID                          Name  Year  Selling_Price  km_Driven  \
# 0         1        Maruti Swift Dzire VDI  2014         450000     145500
# 1         2  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2         3      Honda City 2017-2020 EXi  2006         158000     140000
# 3         4     Hyundai i20 Sportz Diesel  2010         225000     127000
# 4         5        Maruti Swift VXI BSIII  2007         130000     120000
#
#   City_Code State_Code  Postal_Code    Fuel Seller_Type Transmission  \
# 0      CT01       ST15       400001  Diesel  Individual       Manual
# 1      CT28       ST11       834001  Diesel  Individual       Manual
# 2      CT12       ST28       201301  Petrol  Individual       Manual
# 3      CT21       ST27       248001  Diesel  Individual       Manual
# 4      CT03       ST24       600020  Petrol  Individual       Manual
#
#           Owner     Mileage   Engine   Max_Power  Seats    Brand  Model  \
# ...

# %% [markdown]
# Importing another data and merging it with previous data as there is common column name City_code

# %%
path2=r"C:\Users\hasshah\Documents\Capstone3_UsedCarsData (1)\Capstone3_UsedCarsData\City_Master.xlsx"

# %%
car2=pd.read_excel(path2)
car2
# Out:
#    City_Code     City_Name State_Code
# 0       CT01        Mumbai       ST15
# 1       CT02          Pune       ST15
# 2       CT03       Chennai       ST24
# 3       CT04    Coimbatore       ST24
# 4       CT05     Hyderabad       ST25
# 5       CT06        Jaipur       ST22
# 6       CT07         Kochi       ST13
# 7       CT08       Kolkata       ST29
# 8       CT09         Delhi       ST34
# 9       CT10     Bangalore       ST12
# 10      CT11     Ahmedabad       ST07
# 11      CT12         Noida       ST28
# 12      CT13         Patna       ST04
# 13      CT14         Surat       ST07
# 14      CT15  Bhubaneshwar       ST20
# 15      CT16       Gangtok       ST23
# 16      CT17      Vadodara       ST07
# 17      CT18      Ludhiana       ST21
# 18      CT19        Mysore       ST12
# 19      CT20        kanpur       ST28
# 20      CT21      Dehradun       ST27
# 21      CT22        Indore       ST14
# 22      CT23     Mangalore       ST12
# 23      CT24      Thrissur       ST13
# ...

# %%
merged_data = car.merge(car2,on=["City_Code"])
merged_data.head()
# Out:
#    Sales_ID                                 Name  Year  Selling_Price  \
# 0         1               Maruti Swift Dzire VDI  2014         450000
# 1        18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2        48               Toyota Fortuner 4x4 MT  2014        1500000
# 3        71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4       121              Nissan Terrano XL 85 PS  2014         400000
#
#    km_Driven City_Code State_Code_x  Postal_Code    Fuel Seller_Type  ...  \
# 0     145500      CT01         ST15       400001  Diesel  Individual  ...
# 1      53000      CT01         ST15       400001  Diesel  Individual  ...
# 2      77000      CT01         ST15       400001  Diesel      Dealer  ...
# 3      80000      CT01         ST15       400001  Diesel  Individual  ...
# 4      70000      CT01         ST15       400001  Diesel  Individual  ...
#
#           Owner     Mileage   Engine   Max_Power Seats       Brand     Model  \
# ...

# %%
merged_data.drop(['State_Code_x'],axis=1)
# Out:
#       Sales_ID                                 Name  Year  Selling_Price  \
# 0            1               Maruti Swift Dzire VDI  2014         450000
# 1           18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2           48               Toyota Fortuner 4x4 MT  2014        1500000
# 3           71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4          121              Nissan Terrano XL 85 PS  2014         400000
# ...        ...                                  ...   ...            ...
# 7901      7962            Maruti Swift VDI Optional  2015         530000
# 7902      7987           Ford Figo 1.2P Titanium MT  2019         530000
# 7903      8024              Hyundai Santa Fe 4x4 AT  2011        1200000
# 7904      8064       Hyundai Creta 1.6 SX Automatic  2016         890000
# 7905      8107                 Hyundai Verna 1.6 SX  2012         450000
#
#       km_Driven City_Code  Postal_Code    Fuel Seller_Type Transmission  \
# ...

# %%
merged_data.rename(columns={'State_Code_x':'State_Code'})
merged_data.Owner.value_counts()
# Out:
# First Owner             5215
# Second Owner            2016
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: Owner, dtype: int64

# %% [markdown]
# Which brands of car are selling most?

# %%
merged_data['Brand'].value_counts()
# Out:
# Maruti           2367
# Hyundai          1360
# Mahindra          758
# Tata              719
# Honda             466
# Toyota            452
# Ford              388
# Chevrolet         230
# Renault           228
# Volkswagen        185
# BMW               118
# Skoda             104
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               41
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# Daewoo              3
# MG                  3
# Ashok               1
# Opel                1
# Name: Brand, dtype: int64

# %%
merged_data['Brand'].value_counts().head(5)
merged_data['Owner']
# Out:
# 0        First Owner
# 1       Second Owner
# 2        First Owner
# 3        First Owner
# 4        Third Owner
#             ...
# 7901     First Owner
# 7902     First Owner
# 7903    Second Owner
# 7904     First Owner
# 7905    Second Owner
# Name: Owner, Length: 7906, dtype: object

# %% [markdown]
# Are there specific location selling most ?

# %%
merged_data.City_Name.unique()
# Out:
# array(['Mumbai', 'Ranchi', 'Noida', 'Dehradun', 'Chennai', 'Jaipur',
#        'Pune', 'Aurangabad', 'Bangalore', 'Nellore', 'Coimbatore',
#        'kanpur', 'Gangtok', 'Kochi', 'Vadodara', 'Delhi', 'Mysore',
#        'Ludhiana', 'Indore', 'Jamshedpur', 'Kolkata', 'Hyderabad',
#        'Patna', 'Thrissur', 'Surat', 'Vellore', 'Bhubaneshwar',
#        'Ahmedabad', 'Mangalore'], dtype=object)

# %%
merged_data['City_Name'].value_counts()
# Out:
# Delhi           320
# Noida           303
# Mumbai          298
# Coimbatore      294
# Vellore         293
# Chennai         285
# Nellore         281
# Dehradun        280
# Mysore          279
# Kochi           279
# Mangalore       279
# Aurangabad      278
# Ahmedabad       278
# Bangalore       276
# Ranchi          276
# Jaipur          274
# Vadodara        272
# Thrissur        270
# Kolkata         268
# Hyderabad       262
# Gangtok         257
# Patna           257
# Indore          257
# Bhubaneshwar    255
# Pune            250
# Ludhiana        249
# Jamshedpur      247
# kanpur          247
# Surat           242
# Name: City_Name, dtype: int64

# %%
merged_data['City_Name'].value_counts().head(10)
# Out:
# Delhi         320
# Noida         303
# Mumbai        298
# Coimbatore    294
# Vellore       293
# Chennai       285
# Nellore       281
# Dehradun      280
# Mysore        279
# Kochi         279
# Name: City_Name, dtype: int64

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 7905
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales_ID       7906 non-null   int64
#  1   Name           7906 non-null   object
#  2   Year           7906 non-null   int64
#  3   Selling_Price  7906 non-null   int64
#  4   km_Driven      7906 non-null   int64
#  5   City_Code      7906 non-null   object
#  6   State_Code_x   7906 non-null   object
#  7   Postal_Code    7906 non-null   int64
#  8   Fuel           7906 non-null   object
#  9   Seller_Type    7906 non-null   object
#  10  Transmission   7906 non-null   object
#  11  Owner          7906 non-null   object
#  12  Mileage        7906 non-null   object
#  13  Engine         7906 non-null   object
#  14  Max_Power      7906 non-null   object
#  15  Seats          7906 non-null   int64
#  16  Brand          7906 non-null   object
# ...

# %% [markdown]
# Converting categorical data into numerical data for correlation

# %%
merged_data['Fuel']=np.where(merged_data['Fuel']=='Petrol',0,1)
merged_data['Seller_Type']=np.where(merged_data['Seller_Type']=='Individual',0,1)
merged_data['Transmission']=np.where(merged_data['Transmission']=='Manual',0,1)
merged_data['Owner']=np.where(merged_data['Owner']=='Petrol',0,1)

# %%
merged_data['Fuel'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Fuel, dtype: int32

# %%
merged_data['Owner_edited']=car['Owner']

# %%
merged_data['Owner_edited'].value_counts()
# Out:
# First Owner             5215
# Second Owner            2016
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: Owner_edited, dtype: int64

# %%
merged_data[merged_data['Owner_edited']=="First Owner"]['Owner_edited']=1
# Out:
# C:\Users\hasshah\AppData\Local\Temp\ipykernel_4924\4041819447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data[merged_data['Owner_edited']=="First Owner"]['Owner_edited']=1

# %%
merged_data[merged_data['Owner_edited']=='Second Owner']['Owner_edited']=2
# Out:
# C:\Users\hasshah\AppData\Local\Temp\ipykernel_4924\3425856764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data[merged_data['Owner_edited']=='Second Owner']['Owner_edited']=2

# %%
merged_data[merged_data['Owner_edited']=='Third Owner']['Owner_edited']=3
# Out:
# C:\Users\hasshah\AppData\Local\Temp\ipykernel_4924\1329290912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data[merged_data['Owner_edited']=='Third Owner']['Owner_edited']=3

# %%
merged_data[merged_data['Owner_edited']=='Fourth & Above Owner']['Owner_edited']=4
# Out:
# C:\Users\hasshah\AppData\Local\Temp\ipykernel_4924\2473713993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data[merged_data['Owner_edited']=='Fourth & Above Owner']['Owner_edited']=4

# %%
merged_data[merged_data['Owner_edited']=='Test Drive Car']['Owner_edited']=5
# Out:
# C:\Users\hasshah\AppData\Local\Temp\ipykernel_4924\950913626.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_data[merged_data['Owner_edited']=='Test Drive Car']['Owner_edited']=5

# %%
merged_data['Owner_edited'].head()
# Out:
# 0     First Owner
# 1    Second Owner
# 2     Third Owner
# 3     First Owner
# 4     First Owner
# Name: Owner_edited, dtype: object

# %%
merged_data.drop('Owner',axis=1,inplace=True)

# %%
merged_data['Mileage_final']=merged_data['Mileage'].apply(lambda x:' '.join(x.split()[:1]))

# %%
merged_data['Mileage_final'].head()
# Out:
# 0     23.4
# 1     23.0
# 2    12.55
# 3    21.66
# 4    20.45
# Name: Mileage_final, dtype: object

# %%
merged_data.drop(['Mileage'],axis=1,inplace=True)

# %%
merged_data.head()
# Out:
#    Sales_ID                                 Name  Year  Selling_Price  \
# 0         1               Maruti Swift Dzire VDI  2014         450000
# 1        18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2        48               Toyota Fortuner 4x4 MT  2014        1500000
# 3        71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4       121              Nissan Terrano XL 85 PS  2014         400000
#
#    km_Driven City_Code State_Code_x  Postal_Code  Fuel  Seller_Type  ...  \
# 0     145500      CT01         ST15       400001     1            0  ...
# 1      53000      CT01         ST15       400001     1            0  ...
# 2      77000      CT01         ST15       400001     1            1  ...
# 3      80000      CT01         ST15       400001     1            0  ...
# 4      70000      CT01         ST15       400001     1            0  ...
#
#     Engine   Max_Power Seats       Brand     Model              Variant  \
# ...

# %%
merged_data['Engine']=merged_data['Engine'].apply(lambda x:' '.join(x.split()[:1]))

# %%
merged_data.Engine.head()
# Out:
# 0    1248
# 1    1396
# 2    2982
# 3    1498
# 4    1461
# Name: Engine, dtype: object

# %%
merged_data['Max_Power']=merged_data['Max_Power'].apply(lambda x:' '.join(x.split()[:1]))

# %%
merged_data.Max_Power.head()
# Out:
# 0        74
# 1        90
# 2     168.5
# 3    108.62
# 4      83.8
# Name: Max_Power, dtype: object

# %%
merged_data.head()
# Out:
#    Sales_ID                                 Name  Year  Selling_Price  \
# 0         1               Maruti Swift Dzire VDI  2014         450000
# 1        18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2        48               Toyota Fortuner 4x4 MT  2014        1500000
# 3        71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4       121              Nissan Terrano XL 85 PS  2014         400000
#
#    km_Driven City_Code State_Code_x  Postal_Code  Fuel  Seller_Type  ...  \
# 0     145500      CT01         ST15       400001     1            0  ...
# 1      53000      CT01         ST15       400001     1            0  ...
# 2      77000      CT01         ST15       400001     1            1  ...
# 3      80000      CT01         ST15       400001     1            0  ...
# 4      70000      CT01         ST15       400001     1            0  ...
#
#    Engine Max_Power Seats       Brand     Model              Variant  \
# ...

# %%
merged_data.drop(['State_Code_y'],inplace=True,axis=1)

# %%
merged_data.rename(columns={'State_Code_x':'State_Code'})
# Out:
#       Sales_ID                                 Name  Year  Selling_Price  \
# 0            1               Maruti Swift Dzire VDI  2014         450000
# 1           18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2           48               Toyota Fortuner 4x4 MT  2014        1500000
# 3           71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4          121              Nissan Terrano XL 85 PS  2014         400000
# ...        ...                                  ...   ...            ...
# 7901      7962            Maruti Swift VDI Optional  2015         530000
# 7902      7987           Ford Figo 1.2P Titanium MT  2019         530000
# 7903      8024              Hyundai Santa Fe 4x4 AT  2011        1200000
# 7904      8064       Hyundai Creta 1.6 SX Automatic  2016         890000
# 7905      8107                 Hyundai Verna 1.6 SX  2012         450000
#
#       km_Driven City_Code State_Code  Postal_Code  Fuel  Seller_Type  \
# ...

# %%
merged_data.rename(columns={'Mileage_final':'Mileage'})
# Out:
#       Sales_ID                                 Name  Year  Selling_Price  \
# 0            1               Maruti Swift Dzire VDI  2014         450000
# 1           18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2           48               Toyota Fortuner 4x4 MT  2014        1500000
# 3           71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4          121              Nissan Terrano XL 85 PS  2014         400000
# ...        ...                                  ...   ...            ...
# 7901      7962            Maruti Swift VDI Optional  2015         530000
# 7902      7987           Ford Figo 1.2P Titanium MT  2019         530000
# 7903      8024              Hyundai Santa Fe 4x4 AT  2011        1200000
# 7904      8064       Hyundai Creta 1.6 SX Automatic  2016         890000
# 7905      8107                 Hyundai Verna 1.6 SX  2012         450000
#
#       km_Driven City_Code State_Code_x  Postal_Code  Fuel  Seller_Type  \
# ...

# %%
path2=r'C:\Users\hasshah\Documents\Capstone3_UsedCarsData (1)\Capstone3_UsedCarsData\Sales_Status.csv'
sales=pd.read_csv(path2)
sales
# Out:
#       Sales_ID Sold
# 0            1    Y
# 1            2    Y
# 2            3    Y
# 3            4    Y
# 4            5    Y
# ...        ...  ...
# 7901      8124    N
# 7902      8125    N
# 7903      8126    N
# 7904      8127    N
# 7905      8128    N
#
# [7906 rows x 2 columns]

# %%
merged_data2=merged_data.merge(sales,on='Sales_ID',how='outer')
merged_data2.head()
def chec(x):
    if x=='Y':
        x=1
        return x
    else:
        x=0
        return x
        
df=merged_data2['Sold'].apply(chec)
merged_data2['Sold2']=df
merged_data2.head()

brand_data=merged_data2.groupby('Brand').agg({'Sold2':'sum'})
brand_data.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Brand'>

# %%
brand_data.columns
# Out:
# Index(['Sold2'], dtype='object')

# %%
brand_data.sort_values(by='Sold2',ascending=False)[0:5]
# Out:
#           Sold2
# Brand
# Maruti      597
# Hyundai     332
# Mahindra    201
# Tata        178
# Toyota      126

# %% [markdown]
# Are there any specific brands selling more:

# %%
brand_data2=merged_data2.groupby('City_Name').agg({'Sold2':'sum'})
brand_data2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='City_Name'>

# %%
brand_data2.sort_values(by='Sold2',ascending=False)[0:5]
# Out:
#             Sold2
# City_Name
# Mysore         83
# Vellore        81
# Delhi          80
# Noida          80
# Coimbatore     77

# %% [markdown]
# There aren't particulary specific locations selling more, the most selling branches are printed above.

# %%
merged_data['total_years']=2022-merged_data['Year']
merged_data.head()
# Out:
#    Sales_ID                                 Name  Year  Selling_Price  \
# 0         1               Maruti Swift Dzire VDI  2014         450000
# 1        18            Hyundai i20 1.4 CRDi Asta  2012         500000
# 2        48               Toyota Fortuner 4x4 MT  2014        1500000
# 3        71  Volkswagen Ameo 1.5 TDI Comfortline  2017         500000
# 4       121              Nissan Terrano XL 85 PS  2014         400000
#
#    km_Driven City_Code State_Code_x  Postal_Code  Fuel  Seller_Type  ...  \
# 0     145500      CT01         ST15       400001     1            0  ...
# 1      53000      CT01         ST15       400001     1            0  ...
# 2      77000      CT01         ST15       400001     1            1  ...
# 3      80000      CT01         ST15       400001     1            0  ...
# 4      70000      CT01         ST15       400001     1            0  ...
#
#    Engine Max_Power Seats       Brand     Model              Variant  \
# ...

# %% [markdown]
# Construction correlation table to understand which factors are significant in predicting the price of used car

# %%
corr_matrix=merged_data.corr()
corr_matrix
# Out:
#                Sales_ID      Year  Selling_Price  km_Driven  Postal_Code  \
# Sales_ID       1.000000 -0.001304      -0.012125   0.009556    -0.010688
# Year          -0.001304  1.000000       0.412302  -0.428548     0.004898
# Selling_Price -0.012125  0.412302       1.000000  -0.222158     0.008682
# km_Driven      0.009556 -0.428548      -0.222158   1.000000    -0.005680
# Postal_Code   -0.010688  0.004898       0.008682  -0.005680     1.000000
# Fuel           0.034220  0.034351       0.195074   0.274460    -0.005903
# Seller_Type   -0.013680  0.243729       0.386151  -0.202851     0.009965
# Transmission  -0.017498  0.249002       0.590269  -0.201186     0.008425
# Seats         -0.014154 -0.007923       0.041617   0.227259    -0.004804
# total_years    0.001304 -1.000000      -0.412302   0.428548    -0.004898
#
#                    Fuel  Seller_Type  Transmission     Seats  total_years
# Sales_ID       0.034220    -0.013680     -0.017498 -0.014154     0.001304
# ...

# %% [markdown]
# Importing matplotlib and seaborn for visualization
# Constructing heat map to understand which factors are important in deciding car's selling price

# %%
import matplotlib.pyplot as plt
import seaborn as sn
sn.heatmap(corr_matrix, annot=True, cmap="YlGnBu")
plt.show()

# %%
merged_data.to_csv('Excel.csv')

# %% [markdown]
# With the help of heatmap, we understood how variables' effect on the selling price
#
# The summary is as follows:-
# Weak negative correlated variables: Total years and km driven
# Weak positive correlsted variable: Seller type
# Strong positive correlated variable: Transmission type
# So, total there are 5 variables i.e, total years,km driven,seller type and trasmission type which effects the selling price.
